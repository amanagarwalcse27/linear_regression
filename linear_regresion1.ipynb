# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\AMAN\Downloads\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel('price')
plt.scatter(df.area,df.price,marker='+') #marker as shape of point

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price) #the data we know put it in 2D ARRAY ,fit me 2 values jaati h
# Out:
# LinearRegression()

# %%
reg.predict([[3300]]) # y=mx+c
# Out:
# c:\Users\AMAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
m =reg.coef_  #SLOPE 0F EQN
# Out:
# array([135.78767123])

# %%
c= reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color ='red')   #marker as shape of point
plt.show()
